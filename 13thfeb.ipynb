# %%
# Explain why we have to use the Exception class while creating a Custom Exception.
- We use Exception class while creating a Custom Exception so that runtime exceptions is checked

# %%
#Write a python program to print Python Exception Hierarchy.

def treeClass(x, index = 0):
    #return x, index
    
    # print name of the class
    print ("NAME : ",  x.__name__)
    for item in x.__subclasses__():
        #print ("SUBCLASS ", item)
        treeClass(item, index + 3)
    
treeClass(BaseException)
# Out:
# NAME :  BaseException
# NAME :  Exception
# NAME :  TypeError
# NAME :  FloatOperation
# NAME :  MultipartConversionError
# NAME :  StopAsyncIteration
# NAME :  StopIteration
# NAME :  ImportError
# NAME :  ModuleNotFoundError
# NAME :  ZipImportError
# NAME :  OSError
# NAME :  ConnectionError
# NAME :  BrokenPipeError
# NAME :  ConnectionAbortedError
# NAME :  ConnectionRefusedError
# NAME :  ConnectionResetError
# NAME :  RemoteDisconnected
# NAME :  BlockingIOError
# NAME :  ChildProcessError
# NAME :  FileExistsError
# NAME :  FileNotFoundError
# NAME :  IsADirectoryError
# NAME :  NotADirectoryError
# NAME :  InterruptedError
# NAME :  InterruptedSystemCall
# NAME :  PermissionError
# NAME :  ProcessLookupError
# NAME :  TimeoutError
# NAME :  UnsupportedOperation
# NAME :  itimer_error
# NAME :  herror
# NAME :  gaierror
# NAME :  SSLError
# NAME :  SSLCertVerificationError
# NAME :  SSLZeroReturnError
# NAME :  SSLWantWriteError
# NAME :  SSLWantReadError
# ...

# %%
import inspect 

class introspect : 
    
    rollno = 15095
    
        
    def detail(self): 
        print("Enter your detail")
        
        
inp = introspect() 
def message(self): 
        print("Welcome")
inspect.isfunction(message)
# Out:
# True

# %%
#What errors are defined in the ArithmeticError class? Explain any two with an example.


def arithmeticerr(x, index = 0):
    print ("NAME : ",  x.__name__)
    for item in x.__subclasses__():
        #print ("SUBCLASS ", item)
        arithmeticerr(item)
    
arithmeticerr(ArithmeticError)
# Out:
# NAME :  ArithmeticError
# NAME :  FloatingPointError
# NAME :  OverflowError
# NAME :  ZeroDivisionError
# NAME :  DivisionByZero
# NAME :  DivisionUndefined
# NAME :  DecimalException
# NAME :  Clamped
# NAME :  Rounded
# NAME :  Underflow
# NAME :  Overflow
# NAME :  Inexact
# NAME :  Underflow
# NAME :  Overflow
# NAME :  Subnormal
# NAME :  Underflow
# NAME :  DivisionByZero
# NAME :  FloatOperation
# NAME :  InvalidOperation
# NAME :  ConversionSyntax
# NAME :  DivisionImpossible
# NAME :  DivisionUndefined
# NAME :  InvalidContext

# %%
# Why LookupError class is used? Explain with an example KeyError and IndexError.
- LookupError Exception is the Base class for errors raised when something can’t be found.

try :
    import logging
    logging.basicConfig(filename="error.log", level= logging.DEBUG)
    l = [1,2,3,4]
    l[5]
    
except IndexError as e : 
    logging.error(format(e))

# %%
# Explain Import Error. What is Module Not Found Error? 
# Import Error or Module Not found error is raised when you tried to call a module that python doesn't found

try :
    import sandeep 
except ModuleNotFoundError as e : 
    logging.error(format(e))

# %%
# List down some best practices for exception handling in python.
# There are several best practices for exception handling in python i.e listed below :
# Always use a specific exception, Always write a proper message, Always log your exceptions 

try : 
    a = 10/0
    
except ZeroDivisionError as e : 
    logging.error("This is Zero Division Error {}".format(e))
